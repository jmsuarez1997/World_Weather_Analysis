# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
import csv

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | lazaro cardenas
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | longyearbyen
# Processing Record 11 of Set 1 | cabo rojo
# Processing Record 12 of Set 1 | choszczno
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | tateyama
# Processing Record 15 of Set 1 | anori
# Processing Record 16 of Set 1 | conceicao do araguaia
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | matara
# Processing Record 22 of Set 1 | pueblo nuevo
# Processing Record 23 of Set 1 | veraval
# Processing Record 24 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 1 | nome
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | pevek
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | hobyo
# Processing Record 35 of Set 1 | netrakona
# Processing Record 36 of Set 1 | ustka
# Processing Record 37 of Set 1 | havre-saint-pierre
# Processing Record 38 of Set 1 | san alberto
# Processing Record 39 of Set 1 | nantucket
# Processing Record 40 of Set 1 | ugoofaaru
# Processing Record 41 of Set 1 | fortuna
# Processing Record 42 of Set 1 | ostrovnoy
# Processing Record 43 of Set 1 | ponta do sol
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | pacific grove
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | ambilobe
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | mogadishu
# Processing Record 2 of Set 2 | port-cartier
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | szekesfehervar
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | ola
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | severo-kurilsk
# Processing Record 9 of Set 2 | ilyich
# Processing Record 10 of Set 2 | poronaysk
# Processing Record 11 of Set 2 | ust-kulom
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | buraydah
# Processing Record 15 of Set 2 | tumbagaan
# Processing Record 16 of Set 2 | krasnoselkup
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | paamiut
# Processing Record 21 of Set 2 | luderitz
# Processing Record 22 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | clyde river
# Processing Record 29 of Set 2 | filadelfia
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | chuy
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | langsa
# Processing Record 36 of Set 2 | belmonte
# Processing Record 37 of Set 2 | vezirkopru
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | klaksvik
# Processing Record 40 of Set 2 | san cristobal
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | tulsipur
# Processing Record 44 of Set 2 | tyrma
# Processing Record 45 of Set 2 | broken hill
# Processing Record 46 of Set 2 | monteagudo
# Processing Record 47 of Set 2 | ibimirim
# Processing Record 48 of Set 2 | adwa
# Processing Record 49 of Set 2 | te anau
# Processing Record 50 of Set 2 | samarai
# Processing Record 1 of Set 3 | shimsk
# Processing Record 2 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 3 | griffith
# Processing Record 4 of Set 3 | dalwangan
# Processing Record 5 of Set 3 | kavaratti
# Processing Record 6 of Set 3 | tottori
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 3 | azare
# Processing Record 10 of Set 3 | kabinda
# Processing Record 11 of Set 3 | jalu
# Processing Record 12 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 3 | leningradskiy
# Processing Record 14 of Set 3 | palmas
# Processing Record 15 of Set 3 | kamaishi
# Processing Record 16 of Set 3 | camacha
# Processing Record 17 of Set 3 | santa cruz
# Processing Record 18 of Set 3 | yakovlevo
# Processing Record 19 of Set 3 | zeya
# Processing Record 20 of Set 3 | sitka
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | acarau
# Processing Record 24 of Set 3 | petropavl
# Processing Record 25 of Set 3 | los amates
# Processing Record 26 of Set 3 | otjiwarongo
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | harda
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | bolobo
# Processing Record 34 of Set 3 | busselton
# Processing Record 35 of Set 3 | saldanha
# Processing Record 36 of Set 3 | abu kamal
# Processing Record 37 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | geraldton
# Processing Record 41 of Set 3 | mayo
# Processing Record 42 of Set 3 | guhagar
# Processing Record 43 of Set 3 | thio
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | ler
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | la palma
# Processing Record 48 of Set 3 | mar del plata
# Processing Record 49 of Set 3 | thunder bay
# Processing Record 50 of Set 3 | garmsar
# Processing Record 1 of Set 4 | katsuura
# Processing Record 2 of Set 4 | virden
# Processing Record 3 of Set 4 | santa rosalia
# Processing Record 4 of Set 4 | naze
# Processing Record 5 of Set 4 | siilinjarvi
# Processing Record 6 of Set 4 | knyaginino
# Processing Record 7 of Set 4 | hohhot
# Processing Record 8 of Set 4 | lagoa
# Processing Record 9 of Set 4 | provideniya
# Processing Record 10 of Set 4 | yevlax
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | malanje
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | ferrol
# Processing Record 15 of Set 4 | chapar
# Processing Record 16 of Set 4 | lorengau
# Processing Record 17 of Set 4 | sheridan
# Processing Record 18 of Set 4 | japura
# Processing Record 19 of Set 4 | ancud
# Processing Record 20 of Set 4 | bredasdorp
# Processing Record 21 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 4 | sao joao da barra
# Processing Record 23 of Set 4 | lavrentiya
# Processing Record 24 of Set 4 | flinders
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | greenwood
# Processing Record 27 of Set 4 | umm kaddadah
# Processing Record 28 of Set 4 | chincha alta
# Processing Record 29 of Set 4 | yongchang
# Processing Record 30 of Set 4 | tambura
# Processing Record 31 of Set 4 | ambanja
# Processing Record 32 of Set 4 | tomislavgrad
# Processing Record 33 of Set 4 | riyadh
# Processing Record 34 of Set 4 | carbondale
# Processing Record 35 of Set 4 | korem
# Processing Record 36 of Set 4 | huntsville
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | zyryanovsk
# Processing Record 39 of Set 4 | georgetown
# Processing Record 40 of Set 4 | korla
# Processing Record 41 of Set 4 | magdagachi
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 4 | tarnow
# Processing Record 45 of Set 4 | marrakesh
# Processing Record 46 of Set 4 | nogliki
# Processing Record 47 of Set 4 | lima
# Processing Record 48 of Set 4 | zwedru
# Processing Record 49 of Set 4 | ilulissat
# Processing Record 50 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 2 of Set 5 | tuatapere
# Processing Record 3 of Set 5 | samana
# Processing Record 4 of Set 5 | marzuq
# Processing Record 5 of Set 5 | gazli
# Processing Record 6 of Set 5 | manzanillo
# Processing Record 7 of Set 5 | uyemskiy
# Processing Record 8 of Set 5 | kiama
# Processing Record 9 of Set 5 | svetlogorsk
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | miranda de ebro
# Processing Record 12 of Set 5 | hamilton
# Processing Record 13 of Set 5 | matamoros
# Processing Record 14 of Set 5 | spearfish
# Processing Record 15 of Set 5 | betare oya
# Processing Record 16 of Set 5 | jega
# Processing Record 17 of Set 5 | blagoveshchensk
# Processing Record 18 of Set 5 | cairns
# Processing Record 19 of Set 5 | kutum
# Processing Record 20 of Set 5 | nylstroom
# City not found. Skipping...
# Processing Record 21 of Set 5 | kavieng
# Processing Record 22 of Set 5 | sobolevo
# Processing Record 23 of Set 5 | avera
# Processing Record 24 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 5 | morondava
# Processing Record 26 of Set 5 | kununurra
# Processing Record 27 of Set 5 | puerto escondido
# Processing Record 28 of Set 5 | lanzhou
# Processing Record 29 of Set 5 | faya
# Processing Record 30 of Set 5 | sur
# Processing Record 31 of Set 5 | shimoda
# Processing Record 32 of Set 5 | sorkjosen
# Processing Record 33 of Set 5 | guapiles
# Processing Record 34 of Set 5 | ahipara
# Processing Record 35 of Set 5 | grand gaube
# Processing Record 36 of Set 5 | ayan
# Processing Record 37 of Set 5 | gat
# Processing Record 38 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 5 | caluquembe
# Processing Record 40 of Set 5 | matagami
# Processing Record 41 of Set 5 | tahta
# Processing Record 42 of Set 5 | owando
# Processing Record 43 of Set 5 | pervomayskoye
# Processing Record 44 of Set 5 | urussu
# Processing Record 45 of Set 5 | northam
# Processing Record 46 of Set 5 | tricase
# Processing Record 47 of Set 5 | sandnessjoen
# Processing Record 48 of Set 5 | tadine
# Processing Record 49 of Set 5 | airai
# Processing Record 50 of Set 5 | terra nova
# Processing Record 1 of Set 6 | dingle
# Processing Record 2 of Set 6 | hithadhoo
# Processing Record 3 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 6 | esperance
# Processing Record 5 of Set 6 | salalah
# Processing Record 6 of Set 6 | broome
# Processing Record 7 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 6 | arraial do cabo
# Processing Record 9 of Set 6 | bontang
# Processing Record 10 of Set 6 | batemans bay
# Processing Record 11 of Set 6 | butler
# Processing Record 12 of Set 6 | henties bay
# Processing Record 13 of Set 6 | karratha
# Processing Record 14 of Set 6 | kloulklubed
# Processing Record 15 of Set 6 | rio tercero
# Processing Record 16 of Set 6 | dicabisagan
# Processing Record 17 of Set 6 | lerwick
# Processing Record 18 of Set 6 | hasaki
# Processing Record 19 of Set 6 | thyboron
# Processing Record 20 of Set 6 | almeirim
# Processing Record 21 of Set 6 | mokhsogollokh
# Processing Record 22 of Set 6 | nouadhibou
# Processing Record 23 of Set 6 | oranjemund
# Processing Record 24 of Set 6 | fort saint james
# Processing Record 25 of Set 6 | port keats
# Processing Record 26 of Set 6 | sao felix do xingu
# Processing Record 27 of Set 6 | raudeberg
# Processing Record 28 of Set 6 | husavik
# Processing Record 29 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | pisco
# Processing Record 31 of Set 6 | myrtle beach
# Processing Record 32 of Set 6 | porto belo
# Processing Record 33 of Set 6 | windhoek
# Processing Record 34 of Set 6 | upernavik
# Processing Record 35 of Set 6 | harlingen
# Processing Record 36 of Set 6 | khandyga
# Processing Record 37 of Set 6 | wagar
# Processing Record 38 of Set 6 | kruisfontein
# Processing Record 39 of Set 6 | kongolo
# Processing Record 40 of Set 6 | rio gallegos
# Processing Record 41 of Set 6 | aklavik
# Processing Record 42 of Set 6 | guasdualito
# Processing Record 43 of Set 6 | katha
# City not found. Skipping...
# Processing Record 44 of Set 6 | yerbogachen
# Processing Record 45 of Set 6 | morro bay
# Processing Record 46 of Set 6 | aksarayskiy
# Processing Record 47 of Set 6 | domoni
# Processing Record 48 of Set 6 | fowa
# Processing Record 49 of Set 6 | miranda
# Processing Record 50 of Set 6 | hami
# Processing Record 1 of Set 7 | sanchursk
# Processing Record 2 of Set 7 | jizan
# Processing Record 3 of Set 7 | sarakhs
# Processing Record 4 of Set 7 | elban
# Processing Record 5 of Set 7 | hambantota
# Processing Record 6 of Set 7 | elko
# Processing Record 7 of Set 7 | ossora
# Processing Record 8 of Set 7 | nieuw amsterdam
# Processing Record 9 of Set 7 | sinnamary
# Processing Record 10 of Set 7 | qasigiannguit
# Processing Record 11 of Set 7 | ixtapa
# Processing Record 12 of Set 7 | sisimiut
# Processing Record 13 of Set 7 | mugango
# Processing Record 14 of Set 7 | mount gambier
# Processing Record 15 of Set 7 | karaj
# Processing Record 16 of Set 7 | poum
# Processing Record 17 of Set 7 | ingham
# Processing Record 18 of Set 7 | bengkulu
# Processing Record 19 of Set 7 | caravelas
# Processing Record 20 of Set 7 | muroto
# Processing Record 21 of Set 7 | san julian
# Processing Record 22 of Set 7 | muli
# Processing Record 23 of Set 7 | shenjiamen
# Processing Record 24 of Set 7 | bambous virieux
# Processing Record 25 of Set 7 | batabano
# Processing Record 26 of Set 7 | tautira
# Processing Record 27 of Set 7 | sandakan
# Processing Record 28 of Set 7 | lesogorsk
# Processing Record 29 of Set 7 | salaga
# Processing Record 30 of Set 7 | sistranda
# Processing Record 31 of Set 7 | uvinza
# Processing Record 32 of Set 7 | lukiv
# Processing Record 33 of Set 7 | baoqing
# Processing Record 34 of Set 7 | christchurch
# Processing Record 35 of Set 7 | asau
# Processing Record 36 of Set 7 | koslan
# Processing Record 37 of Set 7 | zhangye
# Processing Record 38 of Set 7 | the valley
# Processing Record 39 of Set 7 | tilichiki
# Processing Record 40 of Set 7 | oistins
# Processing Record 41 of Set 7 | savinka
# Processing Record 42 of Set 7 | zyryanka
# Processing Record 43 of Set 7 | reconquista
# Processing Record 44 of Set 7 | bojaya
# City not found. Skipping...
# Processing Record 45 of Set 7 | chernyshevskiy
# Processing Record 46 of Set 7 | constitucion
# Processing Record 47 of Set 7 | saint-denis
# Processing Record 48 of Set 7 | vostok
# Processing Record 49 of Set 7 | teya
# Processing Record 50 of Set 7 | sendafa
# Processing Record 1 of Set 8 | san jeronimo
# Processing Record 2 of Set 8 | kaeo
# Processing Record 3 of Set 8 | kemin
# Processing Record 4 of Set 8 | zhigansk
# Processing Record 5 of Set 8 | suozhen
# Processing Record 6 of Set 8 | kensington
# Processing Record 7 of Set 8 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 8 of Set 8 | umm lajj
# Processing Record 9 of Set 8 | atambua
# Processing Record 10 of Set 8 | bjornevatn
# Processing Record 11 of Set 8 | zharkent
# Processing Record 12 of Set 8 | tibati
# Processing Record 13 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 8 | mount isa
# Processing Record 15 of Set 8 | kerema
# Processing Record 16 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 8 | falam
# Processing Record 18 of Set 8 | correntina
# Processing Record 19 of Set 8 | port elizabeth
# Processing Record 20 of Set 8 | zaykovo
# Processing Record 21 of Set 8 | kamenka
# Processing Record 22 of Set 8 | khandbari
# Processing Record 23 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 24 of Set 8 | goderich
# Processing Record 25 of Set 8 | mariental
# Processing Record 26 of Set 8 | marsh harbour
# Processing Record 27 of Set 8 | sulangan
# Processing Record 28 of Set 8 | hualmay
# Processing Record 29 of Set 8 | zhovti vody
# Processing Record 30 of Set 8 | beidao
# Processing Record 31 of Set 8 | sumenep
# Processing Record 32 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 33 of Set 8 | bulgan
# Processing Record 34 of Set 8 | sabang
# Processing Record 35 of Set 8 | rawson
# Processing Record 36 of Set 8 | arlit
# Processing Record 37 of Set 8 | oranjestad
# Processing Record 38 of Set 8 | rach gia
# Processing Record 39 of Set 8 | tezu
# Processing Record 40 of Set 8 | wattegama
# Processing Record 41 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 8 | laurel
# Processing Record 43 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 8 | touros
# Processing Record 45 of Set 8 | sola
# Processing Record 46 of Set 8 | prainha
# Processing Record 47 of Set 8 | corowa
# Processing Record 48 of Set 8 | porto santo
# Processing Record 49 of Set 8 | kieta
# Processing Record 50 of Set 8 | rab
# City not found. Skipping...
# Processing Record 1 of Set 9 | mosquera
# Processing Record 2 of Set 9 | saint-pierre
# Processing Record 3 of Set 9 | alyangula
# Processing Record 4 of Set 9 | hofn
# Processing Record 5 of Set 9 | olafsvik
# Processing Record 6 of Set 9 | dillon
# Processing Record 7 of Set 9 | evensk
# Processing Record 8 of Set 9 | maumere
# Processing Record 9 of Set 9 | bay city
# Processing Record 10 of Set 9 | sorland
# Processing Record 11 of Set 9 | mahina
# Processing Record 12 of Set 9 | komsomolskiy
# Processing Record 13 of Set 9 | sabla
# Processing Record 14 of Set 9 | tapes
# Processing Record 15 of Set 9 | pittsburg
# Processing Record 16 of Set 9 | palmira
# Processing Record 17 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 9 | sabzevar
# Processing Record 19 of Set 9 | honningsvag
# Processing Record 20 of Set 9 | fartura
# Processing Record 21 of Set 9 | bozuyuk
# Processing Record 22 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 9 | lhokseumawe
# Processing Record 24 of Set 9 | castro alves
# Processing Record 25 of Set 9 | apen
# Processing Record 26 of Set 9 | gamba
# Processing Record 27 of Set 9 | vila velha
# Processing Record 28 of Set 9 | dipkarpaz
# City not found. Skipping...
# Processing Record 29 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 9 | wenatchee
# Processing Record 31 of Set 9 | alofi
# Processing Record 32 of Set 9 | juneau
# Processing Record 33 of Set 9 | sao filipe
# Processing Record 34 of Set 9 | muros
# Processing Record 35 of Set 9 | ahome
# Processing Record 36 of Set 9 | dunedin
# Processing Record 37 of Set 9 | kalmunai
# Processing Record 38 of Set 9 | olga
# Processing Record 39 of Set 9 | dejen
# Processing Record 40 of Set 9 | demyansk
# Processing Record 41 of Set 9 | ayios ioannis
# Processing Record 42 of Set 9 | carndonagh
# Processing Record 43 of Set 9 | meulaboh
# Processing Record 44 of Set 9 | port hedland
# Processing Record 45 of Set 9 | saurimo
# Processing Record 46 of Set 9 | palm beach
# Processing Record 47 of Set 9 | maracaibo
# Processing Record 48 of Set 9 | altar
# Processing Record 49 of Set 9 | kirakira
# Processing Record 50 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 10 | garbolovo
# Processing Record 2 of Set 10 | san quintin
# Processing Record 3 of Set 10 | shakhtinsk
# Processing Record 4 of Set 10 | chapais
# Processing Record 5 of Set 10 | winneba
# Processing Record 6 of Set 10 | antofagasta
# Processing Record 7 of Set 10 | semnan
# Processing Record 8 of Set 10 | coahuayana
# Processing Record 9 of Set 10 | maningrida
# Processing Record 10 of Set 10 | mingaora
# Processing Record 11 of Set 10 | comodoro rivadavia
# Processing Record 12 of Set 10 | dongsheng
# Processing Record 13 of Set 10 | manalongon
# Processing Record 14 of Set 10 | lake havasu city
# Processing Record 15 of Set 10 | sanmenxia
# Processing Record 16 of Set 10 | ondjiva
# Processing Record 17 of Set 10 | vestmannaeyjar
# Processing Record 18 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 10 | hirado
# Processing Record 20 of Set 10 | teguise
# Processing Record 21 of Set 10 | porgera
# Processing Record 22 of Set 10 | astoria
# Processing Record 23 of Set 10 | sao miguel do araguaia
# Processing Record 24 of Set 10 | chumikan
# Processing Record 25 of Set 10 | srednekolymsk
# Processing Record 26 of Set 10 | cortes
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | fairbanks
# Processing Record 29 of Set 10 | huarmey
# Processing Record 30 of Set 10 | makokou
# Processing Record 31 of Set 10 | san felipe
# Processing Record 32 of Set 10 | nieves
# Processing Record 33 of Set 10 | kambia
# Processing Record 34 of Set 10 | hervey bay
# Processing Record 35 of Set 10 | khani
# Processing Record 36 of Set 10 | caldelas
# Processing Record 37 of Set 10 | solnechnyy
# Processing Record 38 of Set 10 | bam
# Processing Record 39 of Set 10 | shingu
# Processing Record 40 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 10 | urusha
# Processing Record 42 of Set 10 | bulawayo
# Processing Record 43 of Set 10 | hungund
# Processing Record 44 of Set 10 | williams lake
# Processing Record 45 of Set 10 | paralimni
# Processing Record 46 of Set 10 | trairi
# Processing Record 47 of Set 10 | tahe
# Processing Record 48 of Set 10 | bundaberg
# Processing Record 49 of Set 10 | salinopolis
# Processing Record 50 of Set 10 | goure
# Processing Record 1 of Set 11 | kemijarvi
# Processing Record 2 of Set 11 | anshun
# Processing Record 3 of Set 11 | acapulco
# Processing Record 4 of Set 11 | anadyr
# Processing Record 5 of Set 11 | kamina
# Processing Record 6 of Set 11 | concarneau
# Processing Record 7 of Set 11 | rocky mountain house
# Processing Record 8 of Set 11 | college
# Processing Record 9 of Set 11 | eucaliptus
# Processing Record 10 of Set 11 | boa vista
# Processing Record 11 of Set 11 | namanga
# Processing Record 12 of Set 11 | lyngseidet
# Processing Record 13 of Set 11 | mareeba
# Processing Record 14 of Set 11 | moose factory
# Processing Record 15 of Set 11 | namibe
# Processing Record 16 of Set 11 | halifax
# Processing Record 17 of Set 11 | eenhana
# Processing Record 18 of Set 11 | moctezuma
# Processing Record 19 of Set 11 | ust-uda
# Processing Record 20 of Set 11 | senno
# Processing Record 21 of Set 11 | koutsouras
# Processing Record 22 of Set 11 | jieshi
# Processing Record 23 of Set 11 | joshimath
# Processing Record 24 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 11 | rocha
# Processing Record 26 of Set 11 | ystad
# Processing Record 27 of Set 11 | rimavska sobota
# Processing Record 28 of Set 11 | dhidhdhoo
# Processing Record 29 of Set 11 | saint-augustin
# Processing Record 30 of Set 11 | darhan
# Processing Record 31 of Set 11 | cidreira
# Processing Record 32 of Set 11 | necochea
# Processing Record 33 of Set 11 | tessalit
# Processing Record 34 of Set 11 | ewa beach
# Processing Record 35 of Set 11 | grand forks
# Processing Record 36 of Set 11 | mayumba
# Processing Record 37 of Set 11 | pokhara
# Processing Record 38 of Set 11 | sept-iles
# Processing Record 39 of Set 11 | tuy hoa
# Processing Record 40 of Set 11 | kasongo-lunda
# Processing Record 41 of Set 11 | phangnga
# Processing Record 42 of Set 11 | murud
# Processing Record 43 of Set 11 | guanica
# Processing Record 44 of Set 11 | llanes
# Processing Record 45 of Set 11 | russell
# Processing Record 46 of Set 11 | zanjan
# Processing Record 47 of Set 11 | muisne
# Processing Record 48 of Set 11 | carsamba
# Processing Record 49 of Set 11 | florence
# Processing Record 50 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 12 | catio
# Processing Record 2 of Set 12 | huntington
# Processing Record 3 of Set 12 | champerico
# Processing Record 4 of Set 12 | laguna
# Processing Record 5 of Set 12 | isabela
# Processing Record 6 of Set 12 | bilma
# Processing Record 7 of Set 12 | boljevac
# Processing Record 8 of Set 12 | burica
# City not found. Skipping...
# Processing Record 9 of Set 12 | vardo
# Processing Record 10 of Set 12 | aswan
# Processing Record 11 of Set 12 | tsiroanomandidy
# Processing Record 12 of Set 12 | rexburg
# Processing Record 13 of Set 12 | longhua
# Processing Record 14 of Set 12 | isangel
# Processing Record 15 of Set 12 | banda aceh
# Processing Record 16 of Set 12 | fort nelson
# Processing Record 17 of Set 12 | ashland
# Processing Record 18 of Set 12 | tiszakarad
# Processing Record 19 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 12 | cockburn town
# Processing Record 21 of Set 12 | thaba nchu
# Processing Record 22 of Set 12 | punta alta
# Processing Record 23 of Set 12 | ivybridge
# Processing Record 24 of Set 12 | camocim
# Processing Record 25 of Set 12 | kenora
# Processing Record 26 of Set 12 | isla mujeres
# Processing Record 27 of Set 12 | beyneu
# Processing Record 28 of Set 12 | bezdan
# Processing Record 29 of Set 12 | nizwa
# Processing Record 30 of Set 12 | barcelos
# Processing Record 31 of Set 12 | itapora
# Processing Record 32 of Set 12 | itarema
# Processing Record 33 of Set 12 | lerik
# Processing Record 34 of Set 12 | madridejos
# Processing Record 35 of Set 12 | kankon
# Processing Record 36 of Set 12 | waingapu
# Processing Record 37 of Set 12 | makakilo city
# Processing Record 38 of Set 12 | alegrete
# Processing Record 39 of Set 12 | seoul
# Processing Record 40 of Set 12 | doha
# Processing Record 41 of Set 12 | santa maria
# Processing Record 42 of Set 12 | boyolangu
# Processing Record 43 of Set 12 | qandala
# Processing Record 44 of Set 12 | ushtobe
# Processing Record 45 of Set 12 | sault sainte marie
# Processing Record 46 of Set 12 | killybegs
# Processing Record 47 of Set 12 | harer
# Processing Record 48 of Set 12 | faanui
# Processing Record 49 of Set 12 | zhuozhou
# City not found. Skipping...
# Processing Record 50 of Set 12 | orichi
# Processing Record 1 of Set 13 | lensk
# Processing Record 2 of Set 13 | bukachacha
# Processing Record 3 of Set 13 | turkan
# Processing Record 4 of Set 13 | whitehorse
# Processing Record 5 of Set 13 | general pico
# Processing Record 6 of Set 13 | west helena
# Processing Record 7 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 13 | the pas
# Processing Record 9 of Set 13 | arkhangelsk
# Processing Record 10 of Set 13 | humboldt
# Processing Record 11 of Set 13 | lac du bonnet
# Processing Record 12 of Set 13 | quatre cocos
# Processing Record 13 of Set 13 | biak
# Processing Record 14 of Set 13 | kananga
# Processing Record 15 of Set 13 | vila franca do campo
# Processing Record 16 of Set 13 | merauke
# Processing Record 17 of Set 13 | pyapon
# Processing Record 18 of Set 13 | makinsk
# Processing Record 19 of Set 13 | inskoy
# Processing Record 20 of Set 13 | jacareacanga
# Processing Record 21 of Set 13 | cabedelo
# Processing Record 22 of Set 13 | pajan
# Processing Record 23 of Set 13 | mezhdurechenskiy
# Processing Record 24 of Set 13 | mukdahan
# Processing Record 25 of Set 13 | entre rios
# Processing Record 26 of Set 13 | san jose
# Processing Record 27 of Set 13 | astaneh-ye ashrafiyeh
# Processing Record 28 of Set 13 | verkhnevilyuysk
# Processing Record 29 of Set 13 | shihezi
# Processing Record 30 of Set 13 | lodwar
# Processing Record 31 of Set 13 | coquimbo
# Processing Record 32 of Set 13 | saint-joseph
# Processing Record 33 of Set 13 | kahului
# Processing Record 34 of Set 13 | aden
# Processing Record 35 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 36 of Set 13 | manggar
# Processing Record 37 of Set 13 | puntarenas
# Processing Record 38 of Set 13 | majene
# Processing Record 39 of Set 13 | svencionys
# Processing Record 40 of Set 13 | richards bay
# Processing Record 41 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 42 of Set 13 | sussex
# Processing Record 43 of Set 13 | la rioja
# Processing Record 44 of Set 13 | swellendam
# Processing Record 45 of Set 13 | rio grande
# Processing Record 46 of Set 13 | glendive
# Processing Record 47 of Set 13 | santo amaro
# Processing Record 48 of Set 13 | sinazongwe
# Processing Record 49 of Set 13 | baraboo
# Processing Record 50 of Set 13 | simdega
# Processing Record 1 of Set 14 | nanortalik
# Processing Record 2 of Set 14 | nuuk
# Processing Record 3 of Set 14 | awbari
# Processing Record 4 of Set 14 | mattru
# Processing Record 5 of Set 14 | verkhnyaya balkariya
# Processing Record 6 of Set 14 | karema
# Processing Record 7 of Set 14 | tura
# Processing Record 8 of Set 14 | neuquen
# Processing Record 9 of Set 14 | kimbe
# Processing Record 10 of Set 14 | buala
# Processing Record 11 of Set 14 | mangrol
# Processing Record 12 of Set 14 | nisia floresta
# Processing Record 13 of Set 14 | keti bandar
# Processing Record 14 of Set 14 | rio esteban
# Processing Record 15 of Set 14 | ambon
# Processing Record 16 of Set 14 | aljezur
# Processing Record 17 of Set 14 | mandalgovi
# Processing Record 18 of Set 14 | kayes
# Processing Record 19 of Set 14 | contamana
# Processing Record 20 of Set 14 | hit
# Processing Record 21 of Set 14 | maniitsoq
# Processing Record 22 of Set 14 | tias
# Processing Record 23 of Set 14 | kidal
# Processing Record 24 of Set 14 | bilibino
# Processing Record 25 of Set 14 | amiens
# Processing Record 26 of Set 14 | kanelovskaya
# Processing Record 27 of Set 14 | totness
# Processing Record 28 of Set 14 | jiwani
# Processing Record 29 of Set 14 | lulea
# Processing Record 30 of Set 14 | gumla
# Processing Record 31 of Set 14 | yar-sale
# Processing Record 32 of Set 14 | krasnyy chikoy
# Processing Record 33 of Set 14 | yumen
# Processing Record 34 of Set 14 | tymovskoye
# Processing Record 35 of Set 14 | trenggalek
# Processing Record 36 of Set 14 | lagunas
# Processing Record 37 of Set 14 | poddorye
# Processing Record 38 of Set 14 | svetlyy
# Processing Record 39 of Set 14 | brentwood
# Processing Record 40 of Set 14 | coaldale
# Processing Record 41 of Set 14 | muncar
# Processing Record 42 of Set 14 | biryusinsk
# Processing Record 43 of Set 14 | andreapol
# Processing Record 44 of Set 14 | lakes entrance
# Processing Record 45 of Set 14 | penzance
# Processing Record 46 of Set 14 | havoysund
# Processing Record 47 of Set 14 | xining
# Processing Record 48 of Set 14 | galle
# Processing Record 49 of Set 14 | berga
# Processing Record 50 of Set 14 | khunti
# Processing Record 1 of Set 15 | waounde
# Processing Record 2 of Set 15 | mastung
# Processing Record 3 of Set 15 | placido de castro
# Processing Record 4 of Set 15 | ornskoldsvik
# Processing Record 5 of Set 15 | dyersburg
# Processing Record 6 of Set 15 | teahupoo
# Processing Record 7 of Set 15 | ca mau
# Processing Record 8 of Set 15 | loksa
# Processing Record 9 of Set 15 | channel-port aux basques
# Processing Record 10 of Set 15 | tiarei
# Processing Record 11 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 15 | kasangulu
# Processing Record 13 of Set 15 | bulalacao
# Processing Record 14 of Set 15 | grindavik
# Processing Record 15 of Set 15 | ulaangom
# Processing Record 16 of Set 15 | shahrud
# Processing Record 17 of Set 15 | corinto
# Processing Record 18 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 19 of Set 15 | novaya zaimka
# Processing Record 20 of Set 15 | zhangjiakou
# Processing Record 21 of Set 15 | ichinoseki
# Processing Record 22 of Set 15 | mendeleyevsk
# Processing Record 23 of Set 15 | marawi
# Processing Record 24 of Set 15 | angoche
# Processing Record 25 of Set 15 | twentynine palms
# Processing Record 26 of Set 15 | mugur-aksy
# Processing Record 27 of Set 15 | witrivier
# City not found. Skipping...
# Processing Record 28 of Set 15 | sawakin
# Processing Record 29 of Set 15 | homer
# Processing Record 30 of Set 15 | roswell
# Processing Record 31 of Set 15 | tabuk
# Processing Record 32 of Set 15 | tambacounda
# Processing Record 33 of Set 15 | xuddur
# Processing Record 34 of Set 15 | kipushi
# Processing Record 35 of Set 15 | portales
# Processing Record 36 of Set 15 | ikongo
# Processing Record 37 of Set 15 | kumluca
# Processing Record 38 of Set 15 | inhambane
# Processing Record 39 of Set 15 | progreso
# Processing Record 40 of Set 15 | praia
# Processing Record 41 of Set 15 | rutul
# Processing Record 42 of Set 15 | puerto leguizamo
# Processing Record 43 of Set 15 | udachnyy
# Processing Record 44 of Set 15 | nabire
# Processing Record 45 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 15 | chilpancingo
# Processing Record 47 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 15 | severobaykalsk
# Processing Record 49 of Set 15 | venice
# Processing Record 50 of Set 15 | los llanos de aridane
# Processing Record 1 of Set 16 | saquena
# Processing Record 2 of Set 16 | half moon bay
# Processing Record 3 of Set 16 | muscat
# Processing Record 4 of Set 16 | karpogory
# Processing Record 5 of Set 16 | gloucester
# Processing Record 6 of Set 16 | hamada
# Processing Record 7 of Set 16 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 16 | snasa
# Processing Record 9 of Set 16 | mildura
# Processing Record 10 of Set 16 | taltal
# Processing Record 11 of Set 16 | grafton
# Processing Record 12 of Set 16 | anjozorobe
# Processing Record 13 of Set 16 | san ramon
# Processing Record 14 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 16 | bazpur
# Processing Record 16 of Set 16 | batsfjord
# Processing Record 17 of Set 16 | hwange
# Processing Record 18 of Set 16 | port hawkesbury
# Processing Record 19 of Set 16 | sinkat
# City not found. Skipping...
# Processing Record 20 of Set 16 | rawa mazowiecka
# Processing Record 21 of Set 16 | diofior
# Processing Record 22 of Set 16 | nishihara
# Processing Record 23 of Set 16 | margate
# Processing Record 24 of Set 16 | adre
# Processing Record 25 of Set 16 | pardi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vaini -21.2000 -175.2000     80.83        73         100
# 1        Jamestown  42.0970  -79.2353     18.72        85         100
# 2  Lazaro Cardenas  17.9583 -102.2000     81.16        55           0
# 3        Cape Town -33.9258   18.4232     72.12        78           0
# 4          Rikitea -23.1203 -134.9692     77.11        71         100
# 5     Puerto Ayora  -0.7393  -90.3518     74.64        78         100
# 6      Port Alfred -33.5906   26.8910     73.15        90          98
# 7      Yellowknife  62.4560 -114.3525     -6.45        81          75
# 8     Longyearbyen  78.2186   15.6401      8.44        66           0
# 9        Cabo Rojo  18.0866  -67.1457     78.98        80          59
#
#    Wind Speed Country                 Date Current Description
# 0       10.65      TO  2022-01-30 23:41:25     overcast clouds
# 1        0.00      US  2022-01-30 23:37:28     overcast clouds
# 2        9.44      MX  2022-01-30 23:41:26           clear sky
# 3        3.00      ZA  2022-01-30 23:41:26           clear sky
# 4        5.77      PF  2022-01-30 23:41:26     overcast clouds
# 5        7.67      EC  2022-01-30 23:39:46     overcast clouds
# 6       16.35      ZA  2022-01-30 23:38:37     overcast clouds
# 7        6.91      CA  2022-01-30 23:37:57          light snow
# 8       21.85      SJ  2022-01-30 23:42:08           clear sky
# 9        4.07      PR  2022-01-30 23:42:08       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vaini      TO -21.2000 -175.2000     80.83        73         100
# 1        Jamestown      US  42.0970  -79.2353     18.72        85         100
# 2  Lazaro Cardenas      MX  17.9583 -102.2000     81.16        55           0
# 3        Cape Town      ZA -33.9258   18.4232     72.12        78           0
# 4          Rikitea      PF -23.1203 -134.9692     77.11        71         100
# 5     Puerto Ayora      EC  -0.7393  -90.3518     74.64        78         100
# 6      Port Alfred      ZA -33.5906   26.8910     73.15        90          98
# 7      Yellowknife      CA  62.4560 -114.3525     -6.45        81          75
# 8     Longyearbyen      SJ  78.2186   15.6401      8.44        66           0
# 9        Cabo Rojo      PR  18.0866  -67.1457     78.98        80          59
#
#    Wind Speed Current Description
# 0       10.65     overcast clouds
# 1        0.00     overcast clouds
# 2        9.44           clear sky
# 3        3.00           clear sky
# 4        5.77     overcast clouds
# 5        7.67     overcast clouds
# 6       16.35     overcast clouds
# 7        6.91          light snow
# 8       21.85           clear sky
# 9        4.07       broken clouds

# %%
import csv
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
